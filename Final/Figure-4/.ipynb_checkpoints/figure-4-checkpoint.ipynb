# %%
# %matplotlib inline
import pandas as pd
from os.path import join
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import skbio
from sklearn.feature_selection import SelectPercentile
from sklearn.cross_validation import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.dummy import DummyClassifier
from skbio.stats.composition import ancom, multiplicative_replacement
# Out:
# /home/johnchase/.conda/envs/da/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ##Load the mapping file

# %%
sample_md = pd.read_csv('map.txt', sep='\t', index_col=0)

# %% [markdown]
# ##Load the OTU table

# %%
home = '/home/office-microbe-files'
table_fp = join(home, 'core_div_out/table_even1000.txt')
table = pd.read_csv(table_fp, sep='\t', skiprows=1, index_col=0, dtype="object")
table.index = table.index.astype(str)

# %% [markdown]
# ##Filter table and map to the intersection

# %%
ids = set(sample_md.index).intersection(table.columns)
table = table[list(ids)]

# %% [markdown]
# #City Machine learning

# %% [markdown]
# ##Create x and Y vectors
# Use feature selection
# Split into test and training sets

# %%
y = sample_md.loc[ids]['City'].values
X = table.values.T

# %%
X = SelectPercentile().fit_transform(X, y)
# Out:
# /home/johnchase/.conda/envs/da/lib/python3.5/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [   34    66    76 ..., 59308 59309 59310] are constant.
#   UserWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# Run SVC For city. The Parameters were previously defined as being the best using grid search

# %%
clf = SVC(C=0.00079432, kernel='linear', random_state=42)

clf.fit(X_train, y_train)

print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()
# Out:
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#   flagstaff       0.78      0.73      0.75       113
#    sandiego       0.59      0.70      0.64       109
#     toronto       0.65      0.57      0.60       113
#
# avg / total       0.67      0.67      0.67       335

# %%
clf_dum = DummyClassifier(strategy='most_frequent')
clf_dum.fit(X_train, y_train)

clf.score(X_test, y_test) /clf_dum.score(X_test, y_test)
# Out:
# 2.0458715596330275

# %%
with plt.rc_context(dict(sns.axes_style("darkgrid"),
                         **sns.plotting_context("notebook", font_scale=2))):
    plt.figure(figsize=(12,10))
    cm = confusion_matrix(y_test, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm, square=True, cmap="YlGnBu")
    ax.set_xticklabels(['Flagstaff', 'San Diego', 'Toronto'])
    ax.set_yticklabels(['Toronto', 'Sandiego', 'Flagstaff'])
    ax.set_ylabel('True label')
    ax.set_xlabel('Predicted label')
    plt.savefig('figure-3-city.svg', dpi=300)

# %% [markdown]
# #Office Machine learning

# %%
y = sample_md.loc[ids]['CityOffice'].values
X = table.values.T

# %%
X = SelectPercentile().fit_transform(X, y)
# Out:
# /home/johnchase/.conda/envs/da/lib/python3.5/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [   34    66    76 ..., 59308 59309 59310] are constant.
#   UserWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=422)

# %%
clf = SVC(C=0.0001584893192, kernel='linear', random_state=42)

clf.fit(X_train, y_train)

print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-1d7fb2e2098d> in <module>()
#       1 clf = SVC(C=0.0001584893192, kernel='linear', random_state=42)
#       2
# ----> 3 clf.fit(X_train, y_train)
#       4
#       5 print("The model is trained on the full development set.")
#
# /home/johnchase/.conda/envs/da/lib/python3.5/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     191
#     192         seed = rnd.randint(np.iinfo('i').max)
# --> 193         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     194         # see comment on the other call to np.iinfo in this file
#     195
#
# /home/johnchase/.conda/envs/da/lib/python3.5/site-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     249                 cache_size=self.cache_size, coef0=self.coef0,
#     250                 gamma=self._gamma, epsilon=self.epsilon,
# --> 251                 max_iter=self.max_iter, random_seed=random_seed)
#     252
#     253         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
clf_dum = DummyClassifier(strategy='most_frequent')
clf_dum.fit(X_train, y_train)

clf.score(X_test, y_test) /clf_dum.score(X_test, y_test)

# %%
Office_labels = ['Flagstaff 1', 'Flagstaff 2', 'Flagstaff 3', 
                 'Sandiego 1', 'Sandiego 2', 'Sandiego 3',
                 'Toronto 1', 'Toronto 2', 'Toronto 3']

with plt.rc_context(dict(sns.axes_style("darkgrid"),
                         **sns.plotting_context("notebook", font_scale=2))):
    plt.figure(figsize=(12,10))
    cm = confusion_matrix(y_test, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm, square=True, cmap="YlGnBu")
    ax.set_xticklabels(Office_labels, rotation=45)
    ax.set_yticklabels(Office_labels[::-1], rotation=0)
    ax.set_ylabel('True label')
    ax.set_xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('figure-3-office.svg', dpi=300)

# %% [markdown]
# ##Flagstaff only

# %%
flag_md = sample_md[sample_md['City'] == 'flagstaff']
ids = set(flag_md.index).intersection(table.columns)
y = flag_md.loc[table[list(ids)].columns]['CityOffice'].values
X = table[list(ids)].values.T

# %%
X = SelectPercentile().fit_transform(X, y)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
clf = SVC(C=0.0031622776601, kernel='linear', random_state=42)

clf.fit(X_train, y_train)

print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()

# %%
clf_dum = DummyClassifier(strategy='most_frequent')
clf_dum.fit(X_train, y_train)

clf.score(X_test, y_test) /clf_dum.score(X_test, y_test)

# %%
Office_labels = ['1', '2', '3']

with plt.rc_context(dict(sns.axes_style("darkgrid"),
                         **sns.plotting_context("notebook", font_scale=2))):
    plt.figure(figsize=(12,10))
    cm = confusion_matrix(y_test, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm, square=True, cmap="YlGnBu")
    ax.set_xticklabels(Office_labels)
    ax.set_yticklabels(Office_labels)
    ax.set_ylabel('True label')
    ax.set_xlabel('Predicted label')
    ax.set_title('Flagstaff')
    plt.savefig('figure-3-flagstaff.svg', dpi=300)

# %% [markdown]
# ##San Diego

# %%
sd_md = sample_md[sample_md['City'] == 'sandiego']
ids = set(sd_md.index).intersection(table.columns)
y = sd_md.loc[table[list(ids)].columns]['CityOffice'].values
X = table[list(ids)].values.T

# %%
X = SelectPercentile().fit_transform(X, y)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
clf = SVC(C=1e-2, kernel='linear')

clf.fit(X_train, y_train)

print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()

# %%
clf_dum = DummyClassifier(strategy='most_frequent')
clf_dum.fit(X_train, y_train)

clf.score(X_test, y_test) /clf_dum.score(X_test, y_test)

# %%
Office_labels = ['1', '2', '3']

with plt.rc_context(dict(sns.axes_style("darkgrid"),
                         **sns.plotting_context("notebook", font_scale=2))):
    plt.figure(figsize=(12,10))
    cm = confusion_matrix(y_test, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm, square=True, cmap="YlGnBu")
    ax.set_xticklabels(Office_labels)
    ax.set_yticklabels(Office_labels[::-1])
    ax.set_ylabel('True label')
    ax.set_xlabel('Predicted label')
    ax.set_title('San Diego')
    plt.savefig('figure-3-sandiego.png', dpi=300)

# %% [markdown]
# Toronto
# --------

# %%
tor_md = sample_md[sample_md['City'] == 'toronto']
ids = set(tor_md.index).intersection(table.columns)
y = tor_md.loc[table[list(ids)].columns]['CityOffice'].values
X = table[list(ids)].values.T

# %%
X = SelectPercentile().fit_transform(X, y)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
clf = SVC(C=1e-2, kernel='linear')

clf.fit(X_train, y_train)

print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()

# %%
clf_dum = DummyClassifier(strategy='most_frequent')
clf_dum.fit(X_train, y_train)

clf.score(X_test, y_test) /clf_dum.score(X_test, y_test)

# %%
Office_labels = ['1', '2', '3']

with plt.rc_context(dict(sns.axes_style("darkgrid"),
                         **sns.plotting_context("notebook", font_scale=2))):
    plt.figure(figsize=(12,10))
    cm = confusion_matrix(y_test, y_pred)
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    ax = sns.heatmap(cm, square=True, cmap="YlGnBu")
    ax.set_xticklabels(Office_labels)
    ax.set_yticklabels(Office_labels[::-1])
    ax.set_ylabel('True label')
    ax.set_xlabel('Predicted label')
    ax.set_title('Toronto')
    plt.savefig('figure-3-toronto.png', dpi=300)

# %%
w_dm = skbio.DistanceMatrix.read('/home/office-microbe-files/core_div_97/bdiv_even1000/unweighted_unifrac_dm.txt')
uw_dm = skbio.DistanceMatrix.read('/home/office-microbe-files/core_div_97/bdiv_even1000/weighted_unifrac_dm.txt')

# %%
sample_md = pd.read_csv('map.txt', sep='\t', index_col=0)

# %%
flagstaff = sample_md[sample_md['City'] == 'flagstaff']
sandiego = sample_md[sample_md['City'] == 'sandiego']
toronto = sample_md[sample_md['City'] == 'toronto']

# %%
def filter_dm_and_map(dm, map_df):
    ids_to_exclude = set(dm.ids) - set(map_df.index.values)
    ids_to_keep = set(dm.ids) - ids_to_exclude
    filtered_dm = dm.filter(ids_to_keep)
    filtered_map = map_df.loc[ids_to_keep]

    return filtered_dm, filtered_map

# %%
filter_dm_and_map(flagstaff.index, )
# Out:
#               16SITS BarcodeSequence BlankExtraction BlankSwab     City  \
# #SampleID
# 66WRG0ZL3SQAC    16S    TAGGCTCGTGCT              no        no  toronto
# UY80K8ZVX32U     16S    AAGTGAAGCGAG              no        no  toronto
# 704U0YCNH37UU    16S    ACTGGCAAACCT              no        no  toronto
# 77BUIVT5QRVAY    16S    TTCACCTGTATC              no        no  toronto
# 54XMAXTDXW01J    16S    CTCCTTAAGGCG              no        no  toronto
# 18O84LVGHGKAZ    16S    CTCCAGGTCATG              no        no  toronto
# 5WLMTMTTS8WDU    16S    TGAGTCATTGAG              no        no  toronto
# 52XJNHXQ4EJ1A    16S    GCCTGCAGTACT              no        no  toronto
# 5OYLQHUA80D5O    16S    GTACTACCTCGG              no        no  toronto
# 4U6H3C4LBSACZ    16S    GTGTTCCCAGAA              no        no  toronto
# 5G7J6C15FE4HD    16S    AGATCTATGCAG              no        no  toronto
# 2S89GLNUTGAVM    16S    TCGGATCTGTGA              no        no  toronto
# 1R55HXJQ8NC6X    16S    CTCGTGAATGAC              no        no  toronto
# 7HHPX97BZWAAN    16S    TTGGTCTCCTCT              no        no  toronto
# 24N5BDEO6WVJ1    16S    TTCCGAATCGGC              no        no  toronto
# 2OXOMXXOKW1O     16S    ACGGATGTTATG              no        no  toronto
# OPZRMUHS6Q62     16S    AACCTCGGATAA              no        no  toronto
# 6SKK0ED1HP7LW    16S    AAGACAGCTATC              no        no  toronto
# 7ELM3E9LLB1QA    16S    TGTGTTACTCCT              no        no  toronto
# 5QTF5WYCZ2F94    16S    TCTGGAACGGTT              no        no  toronto
# 32U5G6L2D4LND    16S    ATCCCAGCATGC              no        no  toronto
# EUVQG7RR6S1M     16S    CCTAGAGAAACT              no        no  toronto
# 1MOZLU9DB4IED    16S    TCAATCGCTTTC              no        no  toronto
# 6JLH5MSE1T11K    16S    ACACAGTCCTGA              no        no  toronto
# 75MJ8MOY5EV5Y    16S    CATGCGGATCCT              no        no  toronto
# 3NJ5RJWIL2SFL    16S    CGTTCTGGTGGT              no        no  toronto
# 5W0D0EJ7F9LOZ    16S    TTCCTGTTAACC              no        no  toronto
# 1ZQYU2L9YU5YF    16S    AGATGTCCGTCA              no        no  toronto
# 4UX91QF2UGN0A    16S    GCTTCCAGACAA              no        no  toronto
# 7Q3J9E8VQ3425    16S    TCAGACCAACTG              no        no  toronto
# ...              ...             ...             ...       ...      ...
# 6RJ0S1EEME1Y3    16S    TCGGTCCATAGC              no        no  toronto
# 43JR2B140G8CC    16S    CACGTTTATTCC              no        no  toronto
# 1FKHCKNTEIEQL    16S    GAAACGGAAACG              no        no  toronto
# 10QFRI7RKL82B    16S    GGTCGTGTCTTG              no        no  toronto
# 2RK8O0GLR452A    16S    CACGACTTGACA              no        no  toronto
# 2CQ72Y0JX6YE0    16S    CTTGGAGGCTTA              no        no  toronto
# 57WHALUCSTFFV    16S    ACGTGGTTCCAC              no        no  toronto
# 4T2FPJEAYW8RL    16S    GACGCTTTGCTG              no        no  toronto
# 7O8PX783UIPTG    16S    ACAGGGTTTGTA              no        no  toronto
# 79EOC4S20LJ56    16S    GCCTATGAGATC              no        no  toronto
# 4LFEMEERENPJF    16S    CAAACCTATGGC              no        no  toronto
# 1XG4WO1GSPVXO    16S    ATCGCTTAAGGC              no        no  toronto
# 2JH6ZNY0WBQ22    16S    ACCATCCAACGA              no        no  toronto
# 7NSPBZP2JYU1E    16S    GCAATAGGAGGA              no        no  toronto
# 4ZTFM9BRY10FN    16S    CCGAACGTCACT              no        no  toronto
# 2BU5WIYHC36TW    16S    ACACCAACACCA              no        no  toronto
# 7G5O8UPIZQAT8    16S    CCATCACATAGG              no        no  toronto
# 4S6EJ4C8DSH7H    16S    CGACACGGAGAA              no        no  toronto
# 4DCCY1W6JVAJ7    16S    GAACCTATGACA              no        no  toronto
# 1PD38BIVXXGXG    16S    ATGCCGGTAATA              no        no  toronto
# 6TOLKN9XLKKWS    16S    GAACAGCTCTAC              no        no  toronto
# 6EUJZKTVRNE8I    16S    GTGAGTCATACC              no        no  toronto
# 3QVA9UGL5PKMR    16S    TGGCCGTTACTG              no        no  toronto
# 3C18OS0JBSDYH    16S    TAGAGCTGCCAT              no        no  toronto
# O1YZ1N8PUKCQ     16S    ATCTAGTGGCAA              no        no  toronto
# 5SDHBDEADHOC2    16S    CCTTCAATGGGA              no        no  toronto
# 34E7LN0ZRJUQB    16S    TTGACGACATCG              no        no  toronto
# 2PK60KKXXMO21    16S    ACATACTGAGCA              no        no  toronto
# 1KWAU7NBOUGA     16S    GGCTAAACTATG              no        no  toronto
# NLYDU47FAOKO     16S    AAGAGCAGAGCC              no        no  toronto
#
#                Cooler           Date   Description Duplicate  Event  \
# #SampleID
# 66WRG0ZL3SQAC     NaN  8/14/13 13:04  T2F.3.Dr.021        no     21
# UY80K8ZVX32U      NaN  8/12/13 15:58  T2F.3.Dr.020        no     20
# 704U0YCNH37UU     NaN  8/14/13 12:43  T3W.3.Dr.021        no     21
# 77BUIVT5QRVAY     NaN  8/12/13 16:10  T3W.3.Dr.020        no     20
# 54XMAXTDXW01J     NaN  8/14/13 12:37  T3C.3.Ca.021        no     21
# 18O84LVGHGKAZ     NaN  8/12/13 16:07  T3C.3.Ca.020        no     20
# 5WLMTMTTS8WDU       1   7/5/13 10:33  T2C.3.Dr.002        no      2
# 52XJNHXQ4EJ1A       1   7/7/13 10:07  T2C.3.Dr.003        no      3
# 5OYLQHUA80D5O       1   7/3/13 10:18  T2C.3.Dr.001        no      1
# 4U6H3C4LBSACZ       2  7/21/13 15:31  T2F.3.Dr.010        no     10
# 5G7J6C15FE4HD     NaN   8/8/13 15:48  T2F.3.Dr.019        no     19
# 2S89GLNUTGAVM     NaN   8/8/13 15:48  T2F.3.Ce.019        no     19
# 1R55HXJQ8NC6X       2  7/21/13 15:15  T3C.3.Ca.010        no     10
# 7HHPX97BZWAAN     NaN   8/8/13 15:36  T3C.3.Ca.019        no     19
# 24N5BDEO6WVJ1       1   8/8/13 15:46  T2C.3.Dr.019        no     19
# 2OXOMXXOKW1O      NaN  8/14/13 12:37  T3C.3.Dr.021        no     21
# OPZRMUHS6Q62      NaN  8/12/13 16:07  T3C.3.Dr.020        no     20
# 6SKK0ED1HP7LW       2  7/21/13 15:37  T1W.3.Ce.010        no     10
# 7ELM3E9LLB1QA       1   8/8/13 16:02  T1W.3.Ce.019        no     19
# 5QTF5WYCZ2F94       1   7/3/13 10:18  T2F.3.Dr.001        no      1
# 32U5G6L2D4LND       1   7/7/13 10:08  T2F.3.Dr.003        no      3
# EUVQG7RR6S1M        1   7/5/13 10:36  T2F.3.Dr.002        no      2
# 1MOZLU9DB4IED       1   7/3/13 11:35  T3C.3.Ca.001        no      1
# 6JLH5MSE1T11K       1   7/7/13 10:16  T3C.3.Ca.003        no      3
# 75MJ8MOY5EV5Y       1   7/5/13 10:49  T3C.3.Ca.002        no      2
# 3NJ5RJWIL2SFL     NaN   8/8/13 15:48  T2F.3.Ca.019        no     19
# 5W0D0EJ7F9LOZ       1   7/3/13 10:18  T2C.3.Ce.001        no      1
# 1ZQYU2L9YU5YF       1   7/5/13 10:34  T2C.3.Ce.002        no      2
# 4UX91QF2UGN0A       1   7/7/13 10:06  T2C.3.Ce.003        no      3
# 7Q3J9E8VQ3425     NaN  8/12/13 15:46  T1F.3.Ce.020        no     20
# ...               ...            ...           ...       ...    ...
# 6RJ0S1EEME1Y3     NaN    5/5/14 0:00  T2F.3.Ce.072        no     72
# 43JR2B140G8CC     NaN    5/5/14 0:00  T3C.3.Ca.072        no     72
# 1FKHCKNTEIEQL     NaN    5/5/14 0:00  T1W.3.Dr.072        no     72
# 10QFRI7RKL82B     NaN    5/5/14 0:00  T1C.3.Dr.072        no     72
# 2RK8O0GLR452A     NaN    4/7/14 0:00  T3F.3.Ca.060        no     60
# 2CQ72Y0JX6YE0     NaN    4/7/14 0:00  T3F.3.Ce.060        no     60
# 57WHALUCSTFFV     NaN    4/7/14 0:00  T3F.3.Dr.060        no     60
# 4T2FPJEAYW8RL     NaN    4/7/14 0:00  T1C.3.Ca.060        no     60
# 7O8PX783UIPTG     NaN    4/7/14 0:00  T2W.3.Ce.060        no     60
# 79EOC4S20LJ56     NaN    4/7/14 0:00  T1F.3.Ce.060        no     60
# 4LFEMEERENPJF     NaN    4/7/14 0:00  T2C.3.Dr.060        no     60
# 1XG4WO1GSPVXO     NaN    4/7/14 0:00  T1W.3.Dr.060        no     60
# 2JH6ZNY0WBQ22     NaN    4/7/14 0:00  T2W.3.Ca.060        no     60
# 7NSPBZP2JYU1E     NaN    4/7/14 0:00  T3C.3.Ca.060        no     60
# 4ZTFM9BRY10FN     NaN    4/7/14 0:00  T2C.3.Ce.060        no     60
# 2BU5WIYHC36TW     NaN    4/7/14 0:00  T1F.3.Dr.060        no     60
# 7G5O8UPIZQAT8     NaN    4/7/14 0:00  T2W.3.Dr.060        no     60
# 4S6EJ4C8DSH7H     NaN    4/7/14 0:00  T3C.3.Dr.060        no     60
# 4DCCY1W6JVAJ7     NaN    4/7/14 0:00  T1W.3.Ce.060        no     60
# 1PD38BIVXXGXG     NaN    4/7/14 0:00  T1C.3.Dr.060        no     60
# 6TOLKN9XLKKWS     NaN    4/7/14 0:00  T2C.3.Ca.060        no     60
# 6EUJZKTVRNE8I     NaN    4/7/14 0:00  T2F.3.Ca.060        no     60
# 3QVA9UGL5PKMR     NaN    4/7/14 0:00  T1W.3.Ca.060        no     60
# 3C18OS0JBSDYH     NaN    4/7/14 0:00  T1C.3.Ce.060        no     60
# O1YZ1N8PUKCQ      NaN    4/7/14 0:00  T2F.3.Ce.060        no     60
# 5SDHBDEADHOC2     NaN    4/7/14 0:00  T2F.3.Dr.060        no     60
# 34E7LN0ZRJUQB     NaN    4/7/14 0:00  T3W.3.Ca.060        no     60
# 2PK60KKXXMO21     NaN    4/7/14 0:00  T3W.3.Ce.060        no     60
# 1KWAU7NBOUGA      NaN    4/7/14 0:00  T3W.3.Dr.060        no     60
# NLYDU47FAOKO      NaN    4/7/14 0:00  T3C.3.Ce.060        no     60
#
#                  ...     PlateLocation     ProjectID Replicate  Row Run  \
# #SampleID        ...
# 66WRG0ZL3SQAC    ...             floor  T2F.3.Dr.021        no    3   1
# UY80K8ZVX32U     ...             floor  T2F.3.Dr.020        no    3   1
# 704U0YCNH37UU    ...              wall  T3W.3.Dr.021        no    3   1
# 77BUIVT5QRVAY    ...              wall  T3W.3.Dr.020        no    3   1
# 54XMAXTDXW01J    ...           ceiling  T3C.3.Ca.021        no    3   1
# 18O84LVGHGKAZ    ...           ceiling  T3C.3.Ca.020        no    3   1
# 5WLMTMTTS8WDU    ...           ceiling  T2C.3.Dr.002        no    3   1
# 52XJNHXQ4EJ1A    ...           ceiling  T2C.3.Dr.003        no    3   1
# 5OYLQHUA80D5O    ...           ceiling  T2C.3.Dr.001        no    3   1
# 4U6H3C4LBSACZ    ...             floor  T2F.3.Dr.010        no    3   1
# 5G7J6C15FE4HD    ...             floor  T2F.3.Dr.019        no    3   1
# 2S89GLNUTGAVM    ...             floor  T2F.3.Ce.019        no    3   1
# 1R55HXJQ8NC6X    ...           ceiling  T3C.3.Ca.010        no    3   1
# 7HHPX97BZWAAN    ...           ceiling  T3C.3.Ca.019        no    3   1
# 24N5BDEO6WVJ1    ...           ceiling  T2C.3.Dr.019        no    3   1
# 2OXOMXXOKW1O     ...           ceiling  T3C.3.Dr.021        no    3   1
# OPZRMUHS6Q62     ...           ceiling  T3C.3.Dr.020        no    3   1
# 6SKK0ED1HP7LW    ...              wall  T1W.3.Ce.010        no    3   1
# 7ELM3E9LLB1QA    ...              wall  T1W.3.Ce.019        no    3   1
# 5QTF5WYCZ2F94    ...             floor  T2F.3.Dr.001        no    3   1
# 32U5G6L2D4LND    ...             floor  T2F.3.Dr.003        no    3   1
# EUVQG7RR6S1M     ...             floor  T2F.3.Dr.002        no    3   1
# 1MOZLU9DB4IED    ...           ceiling  T3C.3.Ca.001        no    3   1
# 6JLH5MSE1T11K    ...           ceiling  T3C.3.Ca.003        no    3   1
# 75MJ8MOY5EV5Y    ...           ceiling  T3C.3.Ca.002        no    3   1
# 3NJ5RJWIL2SFL    ...             floor  T2F.3.Ca.019        no    3   1
# 5W0D0EJ7F9LOZ    ...           ceiling  T2C.3.Ce.001        no    3   1
# 1ZQYU2L9YU5YF    ...           ceiling  T2C.3.Ce.002        no    3   1
# 4UX91QF2UGN0A    ...           ceiling  T2C.3.Ce.003        no    3   1
# 7Q3J9E8VQ3425    ...             floor  T1F.3.Ce.020        no    3   1
# ...              ...               ...           ...       ...  ...  ..
# 6RJ0S1EEME1Y3    ...             floor  T2F.3.Ce.072        no    3   3
# 43JR2B140G8CC    ...           ceiling  T3C.3.Ca.072        no    3   3
# 1FKHCKNTEIEQL    ...              wall  T1W.3.Dr.072        no    3   3
# 10QFRI7RKL82B    ...           ceiling  T1C.3.Dr.072        no    3   3
# 2RK8O0GLR452A    ...             floor  T3F.3.Ca.060        no    3   3
# 2CQ72Y0JX6YE0    ...             floor  T3F.3.Ce.060        no    3   3
# 57WHALUCSTFFV    ...             floor  T3F.3.Dr.060        no    3   3
# 4T2FPJEAYW8RL    ...           ceiling  T1C.3.Ca.060        no    3   3
# 7O8PX783UIPTG    ...              wall  T2W.3.Ce.060        no    3   3
# 79EOC4S20LJ56    ...             floor  T1F.3.Ce.060        no    3   3
# 4LFEMEERENPJF    ...           ceiling  T2C.3.Dr.060        no    3   3
# 1XG4WO1GSPVXO    ...              wall  T1W.3.Dr.060        no    3   3
# 2JH6ZNY0WBQ22    ...              wall  T2W.3.Ca.060        no    3   3
# 7NSPBZP2JYU1E    ...           ceiling  T3C.3.Ca.060        no    3   3
# 4ZTFM9BRY10FN    ...           ceiling  T2C.3.Ce.060        no    3   3
# 2BU5WIYHC36TW    ...             floor  T1F.3.Dr.060        no    3   3
# 7G5O8UPIZQAT8    ...              wall  T2W.3.Dr.060        no    3   3
# 4S6EJ4C8DSH7H    ...           ceiling  T3C.3.Dr.060        no    3   3
# 4DCCY1W6JVAJ7    ...              wall  T1W.3.Ce.060        no    3   3
# 1PD38BIVXXGXG    ...           ceiling  T1C.3.Dr.060        no    3   3
# 6TOLKN9XLKKWS    ...           ceiling  T2C.3.Ca.060        no    3   3
# 6EUJZKTVRNE8I    ...             floor  T2F.3.Ca.060        no    3   3
# 3QVA9UGL5PKMR    ...              wall  T1W.3.Ca.060        no    3   3
# 3C18OS0JBSDYH    ...           ceiling  T1C.3.Ce.060        no    3   3
# O1YZ1N8PUKCQ     ...             floor  T2F.3.Ce.060        no    3   3
# 5SDHBDEADHOC2    ...             floor  T2F.3.Dr.060        no    3   3
# 34E7LN0ZRJUQB    ...              wall  T3W.3.Ca.060        no    3   3
# 2PK60KKXXMO21    ...              wall  T3W.3.Ce.060        no    3   3
# 1KWAU7NBOUGA     ...              wall  T3W.3.Dr.060        no    3   3
# NLYDU47FAOKO     ...           ceiling  T3C.3.Ce.060        no    3   3
#
#                    Time  TimeOfCollection    WeekDay SampleType CityOffice
# #SampleID
# 66WRG0ZL3SQAC  13:04:00          13:04:00  Wednesday     office   toronto2
# UY80K8ZVX32U   15:58:00          15:58:00     Monday     office   toronto2
# 704U0YCNH37UU  12:43:00          12:43:00  Wednesday     office   toronto3
# 77BUIVT5QRVAY  16:10:00          16:10:00     Monday     office   toronto3
# 54XMAXTDXW01J  12:37:00          12:37:00  Wednesday     office   toronto3
# 18O84LVGHGKAZ  16:07:00          16:07:00     Monday     office   toronto3
# 5WLMTMTTS8WDU  10:33:00          10:33:00     Friday     office   toronto2
# 52XJNHXQ4EJ1A  10:07:00          10:07:00     Sunday     office   toronto2
# 5OYLQHUA80D5O  10:18:00          10:18:00  Wednesday     office   toronto2
# 4U6H3C4LBSACZ  15:31:00          15:31:00     Sunday     office   toronto2
# 5G7J6C15FE4HD  15:48:00          15:48:00   Thursday     office   toronto2
# 2S89GLNUTGAVM  15:48:00          15:48:00   Thursday     office   toronto2
# 1R55HXJQ8NC6X  15:15:00          15:15:00     Sunday     office   toronto3
# 7HHPX97BZWAAN  15:36:00          15:36:00   Thursday     office   toronto3
# 24N5BDEO6WVJ1  15:46:00          15:46:00   Thursday     office   toronto2
# 2OXOMXXOKW1O   12:37:00          12:37:00  Wednesday     office   toronto3
# OPZRMUHS6Q62   16:07:00          16:07:00     Monday     office   toronto3
# 6SKK0ED1HP7LW  15:37:00          15:37:00     Sunday     office   toronto1
# 7ELM3E9LLB1QA  16:02:00          16:02:00   Thursday     office   toronto1
# 5QTF5WYCZ2F94  10:18:00          10:18:00  Wednesday     office   toronto2
# 32U5G6L2D4LND  10:08:00          10:08:00     Sunday     office   toronto2
# EUVQG7RR6S1M   10:36:00          10:36:00     Friday     office   toronto2
# 1MOZLU9DB4IED  11:35:00          11:35:00  Wednesday     office   toronto3
# 6JLH5MSE1T11K  10:16:00          10:16:00     Sunday     office   toronto3
# 75MJ8MOY5EV5Y  10:49:00          10:49:00     Friday     office   toronto3
# 3NJ5RJWIL2SFL  15:48:00          15:48:00   Thursday     office   toronto2
# 5W0D0EJ7F9LOZ  10:18:00          10:18:00  Wednesday     office   toronto2
# 1ZQYU2L9YU5YF  10:34:00          10:34:00     Friday     office   toronto2
# 4UX91QF2UGN0A  10:06:00          10:06:00     Sunday     office   toronto2
# 7Q3J9E8VQ3425  15:46:00          15:46:00     Monday     office   toronto1
# ...                 ...               ...        ...        ...        ...
# 6RJ0S1EEME1Y3  10:42:00               NaN     Monday     office   toronto2
# 43JR2B140G8CC  12:12:00               NaN     Monday     office   toronto3
# 1FKHCKNTEIEQL  10:52:00               NaN     Monday     office   toronto1
# 10QFRI7RKL82B  10:48:00               NaN     Monday     office   toronto1
# 2RK8O0GLR452A  12:38:00               NaN     Monday     office   toronto3
# 2CQ72Y0JX6YE0  12:38:00               NaN     Monday     office   toronto3
# 57WHALUCSTFFV  12:38:00               NaN     Monday     office   toronto3
# 4T2FPJEAYW8RL  14:00:00               NaN     Monday     office   toronto1
# 7O8PX783UIPTG  12:05:00               NaN     Monday     office   toronto2
# 79EOC4S20LJ56  14:03:00               NaN     Monday     office   toronto1
# 4LFEMEERENPJF  12:10:00               NaN     Monday     office   toronto2
# 1XG4WO1GSPVXO  14:10:00               NaN     Monday     office   toronto1
# 2JH6ZNY0WBQ22  12:05:00               NaN     Monday     office   toronto2
# 7NSPBZP2JYU1E  12:41:00               NaN     Monday     office   toronto3
# 4ZTFM9BRY10FN  12:10:00               NaN     Monday     office   toronto2
# 2BU5WIYHC36TW  14:03:00               NaN     Monday     office   toronto1
# 7G5O8UPIZQAT8  12:05:00               NaN     Monday     office   toronto2
# 4S6EJ4C8DSH7H  12:41:00               NaN     Monday     office   toronto3
# 4DCCY1W6JVAJ7  14:10:00               NaN     Monday     office   toronto1
# 1PD38BIVXXGXG  14:00:00               NaN     Monday     office   toronto1
# 6TOLKN9XLKKWS  12:10:00               NaN     Monday     office   toronto2
# 6EUJZKTVRNE8I  12:16:00               NaN     Monday     office   toronto2
# 3QVA9UGL5PKMR  14:10:00               NaN     Monday     office   toronto1
# 3C18OS0JBSDYH  14:00:00               NaN     Monday     office   toronto1
# O1YZ1N8PUKCQ   12:16:00               NaN     Monday     office   toronto2
# 5SDHBDEADHOC2  12:16:00               NaN     Monday     office   toronto2
# 34E7LN0ZRJUQB  12:45:00               NaN     Monday     office   toronto3
# 2PK60KKXXMO21  12:45:00               NaN     Monday     office   toronto3
# 1KWAU7NBOUGA   12:45:00               NaN     Monday     office   toronto3
# NLYDU47FAOKO   12:41:00               NaN     Monday     office   toronto3
#
# [513 rows x 27 columns]

# %% [markdown]
# #ANCOM

# %%
pd.options.display.max_colwidth = 200

# %%
table_fp = join(home, 'core_div_out/table_even1000.txt')
table = pd.read_csv(table_fp, sep='\t', skiprows=1, index_col=0).T
table.index = table.index.astype(str)
table.columns = table.columns.astype(str)
# Out:
# /home/johnchase/.conda/envs/da/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
table_ancom = table.loc[:, table.sum(axis=0) > 100]

# %%
table_ancom = pd.DataFrame(multiplicative_replacement(table_ancom), index=table_ancom.index, columns=table_ancom.columns)
table_ancom.dropna(axis=0, inplace=True)
intersect_ids = set(sample_md.index).intersection(set(table_ancom.index))
sample_md_ancom = sample_md.loc[intersect_ids, ]
table_ancom = table_ancom.loc[intersect_ids, ]

# %%
# %%time
results = ancom(table_ancom, sample_md_ancom['City'])
# Out:
# CPU times: user 2min 24s, sys: 59.2 ms, total: 2min 24s
# Wall time: 2min 24s

# %%
sigs = results[results['reject'] == True]

# %%
tax_fp = '/home/office-microbe-files/pick_otus_out_97/uclust_assigned_taxonomy/rep_set_tax_assignments.txt'
taxa_map = pd.read_csv(tax_fp, sep='\t', index_col=0, names=['Taxa', 'none', 'none'])
taxa_map.drop('none', axis=1, inplace=True)
taxa_map.index = taxa_map.index.astype(str)

# %%
taxa_map.loc[sigs.sort_values('W').index.astype(str)][:10]
# Out:
#                                                                                                                                                      Taxa
# #OTU ID
# New.0.CleanUp.ReferenceOTU503973                                            k__Bacteria; p__Cyanobacteria; c__Chloroplast; o__Streptophyta; f__; g__; s__
# 4426298                           k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Bifidobacteriales; f__Bifidobacteriaceae; g__Bifidobacterium; s__
# 225453                                k__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Alteromonadales; f__Alteromonadaceae; g__Cellvibrio; s__
# 4332202                                                                     k__Bacteria; p__Cyanobacteria; c__Chloroplast; o__Streptophyta; f__; g__; s__
# New.0.CleanUp.ReferenceOTU291477      k__Bacteria; p__Bacteroidetes; c__Flavobacteriia; o__Flavobacteriales; f__[Weeksellaceae]; g__Chryseobacterium; s__
# 979315                              k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Actinomycetales; f__Corynebacteriaceae; g__Corynebacterium; s__
# 798634                                             k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Comamonadaceae; g__; s__
# New.0.CleanUp.ReferenceOTU69705                   k__Bacteria; p__Firmicutes; c__Bacilli; o__Bacillales; f__Alicyclobacillaceae; g__Alicyclobacillus; s__
# 112194                                    k__Bacteria; p__Proteobacteria; c__Alphaproteobacteria; o__Rickettsiales; f__Rickettsiaceae; g__Rickettsia; s__
# 147685                                           k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Oxalobacteraceae; g__; s__

# %%
top_ten = taxa_map.loc[sigs.sort_values('W').index.astype(str)][:10]
top_ten.index = top_ten.index.astype(str)

# %%
table_OTUs = table[top_ten.index].copy()/1000
table_OTUs['City'] = sample_md.loc[table_OTUs.index.tolist(), 'City']
table_counts = table_OTUs.groupby('City').describe().unstack().T
table_counts.reset_index(inplace=True)
table_counts = table_counts[table_counts['level_1'].isin(['mean', 'std'])]
table_counts = table_counts.reset_index().set_index('#OTU ID')
table_counts['Taxa'] = taxa_map.loc[table_counts.index, 'Taxa']
table_counts = table_counts.set_index(['Taxa', 'level_1'])
table_counts.drop('index', axis=1, inplace=True)

# %%
cols = ['Flagstaff', 'San Diego', 'Toronto']
df_final = pd.DataFrame(columns=cols)
for i in table_counts.index.get_level_values(level=0):
        df_final.loc[i, cols] = ['{0:.{digits}f} +/- {1:.{digits}f}'.format(mean, std, digits=6) for mean, std in zip(table_counts.loc[i, 'mean'].values[0], table_counts.loc[i, 'std'].values[0])]
# Out:
# /home/johnchase/.conda/envs/da/lib/python3.5/site-packages/IPython/kernel/__main__.py:4: PerformanceWarning: indexing past lexsort depth may impact performance.

# %%
df_final.index.name = 'Taxa'
df_final
# Out:
#                                                                                                                                      Flagstaff  \
# Taxa
# k__Bacteria; p__Proteobacteria; c__Alphaproteobacteria; o__Rickettsiales; f__Rickettsiaceae; g__Rickettsia; s__          0.000278 +/- 0.000804
# k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Oxalobacteraceae; g__; s__                 0.000118 +/- 0.000501
# k__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Alteromonadales; f__Alteromonadaceae; g__Cellvibrio; s__      0.000064 +/- 0.000754
# k__Bacteria; p__Cyanobacteria; c__Chloroplast; o__Streptophyta; f__; g__; s__                                            0.000069 +/- 0.000294
# k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Bifidobacteriales; f__Bifidobacteriaceae; g__Bifidobacterium; s__  0.000036 +/- 0.000404
# k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Comamonadaceae; g__; s__                   0.000296 +/- 0.001100
# k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Actinomycetales; f__Corynebacteriaceae; g__Corynebacterium; s__    0.000051 +/- 0.000333
# k__Bacteria; p__Bacteroidetes; c__Flavobacteriia; o__Flavobacteriales; f__[Weeksellaceae]; g__Chryseobacterium; s__      0.000131 +/- 0.001826
# k__Bacteria; p__Firmicutes; c__Bacilli; o__Bacillales; f__Alicyclobacillaceae; g__Alicyclobacillus; s__                  0.000022 +/- 0.000148
#
#                                                                                                                                      San Diego  \
# Taxa
# k__Bacteria; p__Proteobacteria; c__Alphaproteobacteria; o__Rickettsiales; f__Rickettsiaceae; g__Rickettsia; s__          0.000119 +/- 0.000500
# k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Oxalobacteraceae; g__; s__                 0.000009 +/- 0.000092
# k__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Alteromonadales; f__Alteromonadaceae; g__Cellvibrio; s__      0.000147 +/- 0.000956
# k__Bacteria; p__Cyanobacteria; c__Chloroplast; o__Streptophyta; f__; g__; s__                                            0.000115 +/- 0.000565
# k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Bifidobacteriales; f__Bifidobacteriaceae; g__Bifidobacterium; s__  0.000245 +/- 0.003120
# k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Comamonadaceae; g__; s__                   0.000219 +/- 0.001348
# k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Actinomycetales; f__Corynebacteriaceae; g__Corynebacterium; s__    0.000030 +/- 0.000275
# k__Bacteria; p__Bacteroidetes; c__Flavobacteriia; o__Flavobacteriales; f__[Weeksellaceae]; g__Chryseobacterium; s__      0.000138 +/- 0.002168
# k__Bacteria; p__Firmicutes; c__Bacilli; o__Bacillales; f__Alicyclobacillaceae; g__Alicyclobacillus; s__                  0.000053 +/- 0.000276
#
#                                                                                                                                        Toronto
# Taxa
# k__Bacteria; p__Proteobacteria; c__Alphaproteobacteria; o__Rickettsiales; f__Rickettsiaceae; g__Rickettsia; s__          0.000115 +/- 0.000581
# k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Oxalobacteraceae; g__; s__                 0.000019 +/- 0.000137
# k__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Alteromonadales; f__Alteromonadaceae; g__Cellvibrio; s__      0.000252 +/- 0.001507
# k__Bacteria; p__Cyanobacteria; c__Chloroplast; o__Streptophyta; f__; g__; s__                                            0.000019 +/- 0.000154
# k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Bifidobacteriales; f__Bifidobacteriaceae; g__Bifidobacterium; s__  0.000470 +/- 0.003537
# k__Bacteria; p__Proteobacteria; c__Betaproteobacteria; o__Burkholderiales; f__Comamonadaceae; g__; s__                   0.000106 +/- 0.000627
# k__Bacteria; p__Actinobacteria; c__Actinobacteria; o__Actinomycetales; f__Corynebacteriaceae; g__Corynebacterium; s__    0.000139 +/- 0.000814
# k__Bacteria; p__Bacteroidetes; c__Flavobacteriia; o__Flavobacteriales; f__[Weeksellaceae]; g__Chryseobacterium; s__      0.000825 +/- 0.006377
# k__Bacteria; p__Firmicutes; c__Bacilli; o__Bacillales; f__Alicyclobacillaceae; g__Alicyclobacillus; s__                  0.000089 +/- 0.000359
